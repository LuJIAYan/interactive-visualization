# %% [markdown]
# ## 1.试试通用文档的世界地图

# %%
from pyecharts.charts import Geo

# %%
from pyecharts.faker import Faker

from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.globals import ChartType, SymbolType

def map_world() -> Map:
    c = (
        Map()
        .add("商家A", [list(z) for z in zip(Faker.country, Faker.values())], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-世界地图"),
            visualmap_opts=opts.VisualMapOpts(max_=200),
        )
    )
    return c

# %%
世界地图 = map_world()
世界地图.render()
# Out:
# 'C:\\Users\\LIN\\1sophia_try\\render.html'

# %% [markdown]
# ## 2.实例化

# %%
import pandas as pd
df = pd.read_csv("高收入国家25之30女性年龄人数.csv",encoding='gbk')   #注意编码

# %%
df
# Out:
#      Index                       Variant                          country  \
# 0      141  Estimates and Medium variant              Antigua and Barbuda
# 1      142  Estimates and Medium variant                        Argentina
# 2      143  Estimates and Medium variant                            Aruba
# 3      144  Estimates and Medium variant                        Australia
# 4      145  Estimates and Medium variant                          Austria
# 5      146  Estimates and Medium variant                          Bahamas
# 6      147  Estimates and Medium variant                          Bahrain
# 7      148  Estimates and Medium variant                         Barbados
# 8      149  Estimates and Medium variant                          Belgium
# 9      150  Estimates and Medium variant                Brunei Darussalam
# 10     151  Estimates and Medium variant                           Canada
# 11     152  Estimates and Medium variant                  Channel Islands
# ...

# %%
print(list(df.country))
# Out:
# ['Antigua and Barbuda', 'Argentina', 'Aruba', 'Australia', 'Austria', 'Bahamas', 'Bahrain', 'Barbados', 'Belgium', 'Brunei Darussalam', 'Canada', 'Channel Islands', 'Chile', 'China, Hong Kong SAR', 'China, Macao SAR', 'China, Taiwan Province of China', 'Croatia', 'Cura?ao', 'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'French Polynesia', 'Germany', 'Greece', 'Guam', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'New Caledonia', 'New Zealand', 'Norway', 'Oman', 'Panama', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea', 'Saudi Arabia', 'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Trinidad and Tobago', 'United Arab Emirates', 'United Kingdom', 'United States of America', 'United States Virgin Islands', 'Uruguay', 'Middle-income countries', 'Upper-middle-income countries', 'Albania', 'Algeria', 'Armenia', 'Azerbaijan', 'Belaru
# ...

# %%
print(list(df.number))
# Out:
# ['2', '720', '1', '329', '296', '3', '4', '8', '339', '2', '564', '4', '265', '99', '9', '282', '170', '4', '19', '395', '162', '45', '162', '  1 633', '2', '  2 833', '305', '2', '411', '6', '99', '54', '  2 010', '  3 363', '5', '84', '106', '11', '12', '403', '2', '72', '132', '17', '31', '  1 108', '346', '82', '1', '732', '111', '2', '37', '156', '65', '  1 227', '269', '184', '25', '2', '  1 963', '  6 465', '1', '87', '  64 896', '  35 559', '43', '303', '44', '105', '338', '3', '107', '17', '  2 059', '337', '  19 977', '447', '34', '225', '87', '120', '9', '10', '18', '3', '122', '15', '713', '213', '58', '16', '237', '48', '43', '219', '2', '18', '  1 046', '14', '20', '50', '55', '279', '715', '  4 814', '3', '2', '3', '297', '510', '8', '749', '2', '759', '45', '197', '  29 337', '192', '  1 377', '6', '109', '6', '169', '169', '32', '99', '2', '813', '85', '11', '129', '183', '58', '  14 497', '  2 523', '208', '2', '65', '69', '28', '26', '1', '29', '376', '729', '54', 
# ...

# %%
# 迭代
高收入国家25至30女性人数 = zip(list(df.country),list(df.number))
print(高收入国家25至30女性人数)

# %%
# 元组的列表,一对一
高收入国家25至30女性人数 =list(zip(list(df.country),list(df.number)))
print(高收入国家25至30女性人数)
# Out:
# [('Antigua and Barbuda', '2'), ('Argentina', '720'), ('Aruba', '1'), ('Australia', '329'), ('Austria', '296'), ('Bahamas', '3'), ('Bahrain', '4'), ('Barbados', '8'), ('Belgium', '339'), ('Brunei Darussalam', '2'), ('Canada', '564'), ('Channel Islands', '4'), ('Chile', '265'), ('China, Hong Kong SAR', '99'), ('China, Macao SAR', '9'), ('China, Taiwan Province of China', '282'), ('Croatia', '170'), ('Cura?ao', '4'), ('Cyprus', '19'), ('Czechia', '395'), ('Denmark', '162'), ('Estonia', '45'), ('Finland', '162'), ('France', '  1 633'), ('French Polynesia', '2'), ('Germany', '  2 833'), ('Greece', '305'), ('Guam', '2'), ('Hungary', '411'), ('Iceland', '6'), ('Ireland', '99'), ('Israel', '54'), ('Italy', '  2 010'), ('Japan', '  3 363'), ('Kuwait', '5'), ('Latvia', '84'), ('Lithuania', '106'), ('Luxembourg', '11'), ('Malta', '12'), ('Netherlands', '403'), ('New Caledonia', '2'), ('New Zealand', '72'), ('Norway', '132'), ('Oman', '17'), ('Panama', '31'), ('Poland', '  1 108'), ('Portugal', 
# ...

# %%
from pyecharts.faker import Faker

from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.globals import ChartType, SymbolType

def map_world() -> Map:
    c = (
        Map()
        .add("高收入国家25至30女性人数", [list(z) for z in zip(Faker.country, Faker.values())], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-世界地图"),
            visualmap_opts=opts.VisualMapOpts(max_=200),
        )
    )
    return c

# %%
世界地图1 = map_world()
世界地图1.render()
# Out:
# 'C:\\Users\\LIN\\1sophia_try\\render.html'

# %%
import pandas as pd
df = pd.read_csv("高收入国家男性.csv",encoding='gbk')
df
# Out:
#     Index                       Variant                        countries  \
# 0     141  Estimates and Medium variant              Antigua and Barbuda
# 1     142  Estimates and Medium variant                        Argentina
# 2     143  Estimates and Medium variant                            Aruba
# 3     144  Estimates and Medium variant                        Australia
# 4     145  Estimates and Medium variant                          Austria
# 5     146  Estimates and Medium variant                          Bahamas
# 6     147  Estimates and Medium variant                          Bahrain
# 7     148  Estimates and Medium variant                         Barbados
# 8     149  Estimates and Medium variant                          Belgium
# 9     150  Estimates and Medium variant                Brunei Darussalam
# 10    151  Estimates and Medium variant                           Canada
# 11    152  Estimates and Medium variant                  Channel Islands
# ...

# %%
高收入国家25至30男性人数 =list(zip(list(df.countries),list(df.number)))
print(高收入国家25至30男性人数)
# Out:
# [('Antigua and Barbuda', '   1'), ('Argentina', '   726'), ('Aruba', '   1'), ('Australia', '   344'), ('Austria', '   223'), ('Bahamas', '   3'), ('Bahrain', '   6'), ('Barbados', '   7'), ('Belgium', '   355'), ('Brunei Darussalam', '   2'), ('Canada', '   550'), ('Channel Islands', '   4'), ('Chile', '   272'), ('China, Hong Kong SAR', '   113'), ('China, Macao SAR', '   10'), ('China, Taiwan Province of China', '   338'), ('Croatia', '   133'), ('Cura?ao', '   4'), ('Cyprus', '   17'), ('Czechia', '   381'), ('Denmark', '   158'), ('Estonia', '   31'), ('Finland', '   147'), ('France', '  1 649'), ('French Polynesia', '   2'), ('Germany', '  2 019'), ('Greece', '   281'), ('Guam', '   5'), ('Hungary', '   377'), ('Iceland', '   6'), ('Ireland', '   99'), ('Israel', '   59'), ('Italy', '  1 874'), ('Japan', '  2 822'), ('Kuwait', '   11'), ('Latvia', '   53'), ('Lithuania', '   80'), ('Luxembourg', '   10'), ('Malta', '   11'), ('Netherlands', '   396'), ('New Caledonia', '   3'),
# ...

# %%
from pyecharts.faker import Faker

from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.globals import ChartType, SymbolType

def map_world() -> Map:
    c = (
        Map()
        .add("高收入国家25至30男性人数", [list(z) for z in zip(Faker.country, Faker.values())], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-世界地图"),
            visualmap_opts=opts.VisualMapOpts(max_=200),
        )
    )
    return c

# %%
世界地图2 = map_world()
世界地图2.render()
# Out:
# 'C:\\Users\\LIN\\1sophia_try\\render.html'

# %% [markdown]
# 通过对比地图1，2可以看出，中国和巴西在全球高收入国家25-30岁男女比例差异最大。中国25-30岁（男性111000，女性71000）和非洲巴西20-30岁（男性61000，女性100000)，在25-30的年龄段里，中国男性比较多，巴西女性较多。具体原因有待根据国家历史，经济、教育等深入探讨...

# %% [markdown]
# 更多资料的可视化要先学好数据的清洗，为了做出可视化，手动对数据表格进行操作，研究主题有些局限，有待改进..
